# %% [markdown]
# # GDELT Raw Data File Collection

# %% [markdown]
# ### This file will follow the steps below to collect the gdelt data
# #### 1. This file will download the master file from official gdelt website.
# #### 2. Based on the user preference it will download the data from gdelt in compressed format.
# #### 3. Un-compressing the downloaded files
# #### 4. Combining the un-compressed files into one single csv file
# #### 5. Push the combined csv file to NoSQL MongoDB

# %% [markdown]
# ### Download the Master file

# %% [markdown]
# #### Install wget

# %%
# %pip install wget
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py): started
#   Building wheel for wget (setup.py): finished with status 'done'
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=55b656c4ef6be77d3abe245f16091b9bfcbe8438c26b60e8d74bc7dc21569d01
#   Stored in directory: c:\users\abhinav\appdata\local\pip\cache\wheels\04\5f\3e\46cc37c5d698415694d83f607f833f83f0149e49b3af9d0f38
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %% [markdown]
# #### Check if the old master file already present in the directory. If it's present then delete the old file and download the latest one from GDELT

# %%
import os
file_path = r".\master\masterfilelist.txt"
if os.path.isfile(file_path):
  os.remove(file_path)
  print("Old Master file existed and has been deleted")
else:
  print("Old Master file not found!")
# Out:
# Old Master file not found!

# %% [markdown]
# #### Download the master file which maps the raw data files

# %%
import wget
path_master = r".\master"
wget.download("http://data.gdeltproject.org/gdeltv2/masterfilelist.txt", out = path_master)
# Out:
#   2% [.                                                                       ]  1802240 / 82533966
#   4% [...                                                                     ]  3940352 / 82533966
#   7% [.....                                                                   ]  6168576 / 82533966
#  10% [.......                                                                 ]  8536064 / 82533966
#  12% [........                                                                ] 10223616 / 82533966
#  13% [.........                                                               ] 11329536 / 82533966
#  17% [............                                                            ] 14385152 / 82533966
#  19% [.............                                                           ] 15761408 / 82533966
#  21% [...............                                                         ] 17825792 / 82533966
#  25% [..................                                                      ] 21069824 / 82533966
#  28% [....................                                                    ] 23420928 / 82533966
#  31% [......................                                                  ] 25624576 / 82533966
#  33% [........................                                                ] 27860992 / 82533966
#  36% [..........................                                              ] 30072832 / 82533966
#  39% [............................                                            ] 32268288 / 82533966
#  41% [..............................                                          ] 34512896 / 82533966
#  44% [................................                                        ] 36839424 / 82533966
#  47% [..................................                                      ] 39034880 / 82533966
#  50% [....................................                                    ] 41361408 / 82533966
#  52% [.....................................                                   ] 43532288 / 82533966
#  55% [.......................................                                 ] 45711360 / 82533966
#  58% [.........................................                               ] 47874048 / 82533966
#  60% [...........................................                             ] 50053120 / 82533966
#  63% [.............................................                           ] 52289536 / 82533966
#  66% [...............................................                         ] 54583296 / 82533966
#  68% [.................................................                       ] 56393728 / 82533966
#  71% [...................................................                     ] 59031552 / 82533966
#  72% [....................................................                    ] 59908096 / 82533966
#  75% [......................................................                  ] 61980672 / 82533966
#  77% [.......................................................                 ] 64159744 / 82533966
#  80% [..........................................................              ] 66494464 / 82533966
#  83% [...........................................................             ] 68550656 / 82533966
#  85% [.............................................................           ] 70737920 / 82533966
#  88% [...............................................................         ] 73023488 / 82533966
#  91% [.................................................................       ] 75407360 / 82533966
#  93% [...................................................................     ] 77545472 / 82533966
#  96% [.....................................................................   ] 79675392 / 82533966
#  99% [....................................................................... ] 81846272 / 82533966
# 100% [........................................................................] 82533966 / 82533966
# '.\\master/masterfilelist.txt'

# %% [markdown]
# ### Read the master file into a dataframe

# %%
import pandas as pd
header_list = ['A','B','C']
df = pd.read_csv(r".\master\masterfilelist.txt", sep= ' ', names = header_list)

# %%
df.head()
# Out:
#           A                                 B  \
# 0    150383  297a16b493de7cf6ca809a7cc31d0b93
# 1    318084  bb27f78ba45f69a17ea6ed7755e9f8ff
# 2  10768507  ea8dde0beb0ba98810a92db068c0ce99
# 3    149211  2a91041d7e72b0fc6a629e2ff867b240
# 4    339037  dec3f427076b716a8112b9086c342523
#
#                                                    C
# 0  http://data.gdeltproject.org/gdeltv2/201502182...
# 1  http://data.gdeltproject.org/gdeltv2/201502182...
# 2  http://data.gdeltproject.org/gdeltv2/201502182...
# 3  http://data.gdeltproject.org/gdeltv2/201502182...
# 4  http://data.gdeltproject.org/gdeltv2/201502182...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772281 entries, 0 to 772280
# Data columns (total 3 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   A       772281 non-null  object
#  1   B       772226 non-null  object
#  2   C       772226 non-null  object
# dtypes: object(3)
# memory usage: 17.7+ MB

# %% [markdown]
# ### Fetch all the export table files of event data
# #### This will download only the event data from GDELT

# %%
list_of_export_table = []

# %%
for i in df['C']:
    if 'export' in str(i):
        list_of_export_table.append(i)

# %%
len(list_of_export_table)
# Out:
# 257407

# %%
list_of_export_table
# Out:
# ['http://data.gdeltproject.org/gdeltv2/20150218230000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150218231500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150218233000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150218234500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219000000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219001500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219003000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219004500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219010000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219011500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219013000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219014500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219020000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219021500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219023000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219024500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219030000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219031500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219033000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219040000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219034500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219041500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219043000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219044500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219050000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219051500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219053000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219054500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219060000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219061500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219063000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219064500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219071500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219074500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219080000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219093000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219094500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219101500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219103000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219104500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219110000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219111500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219113000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219114500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219120000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219121500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219123000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219124500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219130000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219131500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219133000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219134500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219140000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219141500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219143000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219144500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219150000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219151500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219153000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219154500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219160000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219161500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219163000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219164500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219170000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219171500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219173000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219174500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219180000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219181500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219183000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219184500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219190000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219191500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219193000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219194500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219200000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219201500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219203000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219204500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219210000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219211500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219213000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219214500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219220000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219221500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219223000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219224500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219230000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219231500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219233000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150219234500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220000000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220001500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220003000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220004500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220010000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220011500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220013000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220014500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220020000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220021500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220023000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220024500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220030000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220033000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220031500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220034500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220040000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220041500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220043000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220044500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220050000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220051500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220053000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220054500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220060000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220061500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220063000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220064500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220070000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220071500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220073000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220074500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220080000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220081500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220083000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220084500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220090000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220091500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220093000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220094500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220100000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220101500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220103000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220104500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220110000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220111500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220113000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220114500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220120000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220121500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220123000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220124500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220130000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220131500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220133000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220134500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220140000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220141500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220143000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220144500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220150000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220151500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220153000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220154500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220160000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220161500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220163000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220164500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220170000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220171500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220173000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220174500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220180000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220181500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220183000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220184500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220190000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220191500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220193000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220194500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220200000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220201500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220203000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220204500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220210000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220211500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220213000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220214500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220220000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220221500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220223000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150220224500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150
.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150301100000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150301101500.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150301103000.export.CSV.zip',
#  'http://data.gdeltproject.org/gdeltv2/20150301104500.export.CSV.zip',
#  ...]

# %% [markdown]
# ### Download the x number of files from today
# #### This will download all the files going back from the day the code will be run

# %%
print("ENTER THE NUMEBR OF FILES YOU WANT TO DOWNLOAD")
num = input()
# Out:
# ENTER THE NUMEBR OF FILES YOU WANT TO DOWNLOAD
# 60

# %%
path_zip = r'.\zip_data'

# %%
import shutil
if len(os.listdir(path_zip)) == 0:
    print("Directory is empty")
else:
    shutil.rmtree(path_zip)

# %%
os.mkdir(path_zip)

# %%
for i in list_of_export_table[-int(num):]:
    wget.download(i, out = path_zip)
# Out:
# 100% [..............................................................................] 61677 / 61677

# %%
len(os.listdir(path_zip))
# Out:
# 60

# %% [markdown]
# ### Unzip the downloaded files to a new folder

# %%
import shutil

# %%
path_csv = r'.\csv_data'

# %%
import shutil
if len(os.listdir(path_csv)) == 0:
    print("Directory is empty")
else:
    shutil.rmtree(path_csv)

# %%
os.mkdir(path_csv)

# %%
file_names = os.listdir(path_zip)

# %%
for i in file_names:
    shutil.unpack_archive(path_zip + '\\' + i, path_csv)

# %% [markdown]
# ### Combine all the CSV into one

# %%
header = ['GLOBALEVENTID', 
            'SQLDATE', 
            'MonthYear',
            'Year', 
            'FractionDate',
            'Actor1Code', 
            'Actor1Name', 
            'Actor1CountryCode',
            'Actor1KnownGroupCode',
            'Actor1EthnicCode',
            'Actor1Religion1Code',
            'Actor1Religion2Code',
            'Actor1Type1Code',
            'Actor1Type2Code',
            'Actor1Type3Code',
            'Actor2Code',
            'Actor2Name',
            'Actor2CountryCode',
            'Actor2KnownGroupCode',
            'Actor2EthnicCode',
            'Actor2Religion1Code',
            'Actor2Religion2Code',
            'Actor2Type1Code',
            'Actor2Type2Code',
            'Actor2Type3Code',
            'IsRootEvent',
            'EventCode',
            'EventBaseCode',
            'EventRootCode',
            'QuadClass',
            'GoldsteinScale',
            'NumMentions',
            'NumSources',
            'NumArticles',
            'AvgTone',
            'Actor1Geo_Type',
            'Actor1Geo_FullName',
            'Actor1Geo_CountryCode',
            'Actor1Geo_ADM1Code',
            'Actor1Geo_ADM2Code',
            'Actor1Geo_Lat',
            'Actor1Geo_Long',
            'Actor1Geo_FeatureID',
            'Actor2Geo_Type',
            'Actor2Geo_FullName',
            'Actor2Geo_CountryCode',
            'Actor2Geo_ADM1Code',
            'Actor2Geo_ADM2Code',
            'Actor2Geo_Lat',
            'Actor2Geo_Long',
            'Actor2Geo_FeatureID',
            'ActionGeo_Type',
            'ActionGeo_FullName',
            'ActionGeo_CountryCode',
            'ActionGeo_ADM1Code',
            'ActionGeo_ADM2Code',
            'ActionGeo_Lat',
            'ActionGeo_Long',
            'ActionGeo_FeatureID',
            'DATEADDED',
            'SOURCEURL']

# %%
len(header)
# Out:
# 61

# %%
import glob
files = os.path.join(path_csv, "*.csv")

# %%
files
# Out:
# '.\\csv_data\\*.csv'

# %%
files = glob.glob(files)

# %%
final_csv = pd.concat([pd.read_csv(f, sep = '\t', names = header) for f in files])

# %%
final_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 72998 entries, 0 to 862
# Data columns (total 61 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   GLOBALEVENTID          72998 non-null  int64
#  1   SQLDATE                72998 non-null  int64
#  2   MonthYear              72998 non-null  int64
#  3   Year                   72998 non-null  int64
#  4   FractionDate           72998 non-null  float64
#  5   Actor1Code             65954 non-null  object
#  6   Actor1Name             65954 non-null  object
#  7   Actor1CountryCode      41431 non-null  object
#  8   Actor1KnownGroupCode   1077 non-null   object
#  9   Actor1EthnicCode       487 non-null    object
#  10  Actor1Religion1Code    1068 non-null   object
#  11  Actor1Religion2Code    230 non-null    object
#  12  Actor1Type1Code        31166 non-null  object
#  13  Actor1Type2Code        2205 non-null   object
#  14  Actor1Type3Code        44 non-null     object
#  15  Actor2Code             52471 non-null  object
#  16  Actor2Name             52471 non-null  object
#  17  Actor2CountryCode      32896 non-null  object
#  18  Actor2KnownGroupCode   891 non-null    object
#  19  Actor2EthnicCode       393 non-null    object
#  20  Actor2Religion1Code    1000 non-null   object
#  21  Actor2Religion2Code    246 non-null    object
#  22  Actor2Type1Code        24699 non-null  object
#  23  Actor2Type2Code        1515 non-null   object
#  24  Actor2Type3Code        44 non-null     object
#  25  IsRootEvent            72998 non-null  int64
#  26  EventCode              72998 non-null  int64
#  27  EventBaseCode          72998 non-null  int64
#  28  EventRootCode          72998 non-null  int64
#  29  QuadClass              72998 non-null  int64
#  30  GoldsteinScale         72998 non-null  float64
#  31  NumMentions            72998 non-null  int64
#  32  NumSources             72998 non-null  int64
#  33  NumArticles            72998 non-null  int64
#  34  AvgTone                72998 non-null  float64
#  35  Actor1Geo_Type         72998 non-null  int64
#  36  Actor1Geo_FullName     64229 non-null  object
#  37  Actor1Geo_CountryCode  64254 non-null  object
#  38  Actor1Geo_ADM1Code     64254 non-null  object
#  39  Actor1Geo_ADM2Code     39509 non-null  object
#  40  Actor1Geo_Lat          64229 non-null  float64
#  41  Actor1Geo_Long         64233 non-null  float64
#  42  Actor1Geo_FeatureID    64254 non-null  object
#  43  Actor2Geo_Type         72998 non-null  int64
#  44  Actor2Geo_FullName     51142 non-null  object
#  45  Actor2Geo_CountryCode  51159 non-null  object
#  46  Actor2Geo_ADM1Code     51159 non-null  object
#  47  Actor2Geo_ADM2Code     27563 non-null  object
#  48  Actor2Geo_Lat          51142 non-null  float64
#  49  Actor2Geo_Long         51146 non-null  float64
#  50  Actor2Geo_FeatureID    51159 non-null  object
#  51  ActionGeo_Type         72998 non-null  int64
#  52  ActionGeo_FullName     71115 non-null  object
#  53  ActionGeo_CountryCode  71136 non-null  object
#  54  ActionGeo_ADM1Code     71136 non-null  object
#  55  ActionGeo_ADM2Code     38326 non-null  object
#  56  ActionGeo_Lat          71115 non-null  float64
#  57  ActionGeo_Long         71118 non-null  float64
#  58  ActionGeo_FeatureID    71136 non-null  object
#  59  DATEADDED              72998 non-null  int64
#  60  SOURCEURL              72998 non-null  object
# dtypes: float64(9), int64(16), object(36)
# memory usage: 34.5+ MB

# %%
final_csv.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0     1059110586  20210818     202108  2021     2021.6247        CRM
# 1     1059110587  20210818     202108  2021     2021.6247        MED
# 2     1059110588  20210818     202108  2021     2021.6247        MED
# 3     1059110589  20210818     202108  2021     2021.6247        MED
# 4     1059110590  20210818     202108  2021     2021.6247        MED
#
#   Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  ...  \
# 0    THIEVES               NaN                  NaN              NaN  ...
# 1  COLUMNIST               NaN                  NaN              NaN  ...
# 2  COLUMNIST               NaN                  NaN              NaN  ...
# 3  COLUMNIST               NaN                  NaN              NaN  ...
# 4  COLUMNIST               NaN                  NaN              NaN  ...
#
#   ActionGeo_Type                        ActionGeo_FullName  \
# 0              3  San Francisco, California, United States
# 1              1                                   Germany
# 2              4         Helsinki, Eteläuomen Läi, Finland
# 3              4      Katajanokka, Uusimaa Region, Finland
# 4              4         Helsinki, Eteläuomen Läi, Finland
#
#   ActionGeo_CountryCode ActionGeo_ADM1Code ActionGeo_ADM2Code ActionGeo_Lat  \
# 0                    US               USCA                NaN       37.7749
# 1                    GM                 GM                NaN       51.5000
# 2                    FI               FI13              16230       60.1756
# 3                    FI               FI35              16230       60.1664
# 4                    FI               FI13              16230       60.1756
#
#   ActionGeo_Long ActionGeo_FeatureID       DATEADDED  \
# 0      -122.4190              277593  20220818074500
# 1        10.5000                  GM  20220818074500
# 2        24.9342            -1364995  20220818074500
# 3        24.9692            -1369554  20220818074500
# 4        24.9342            -1364995  20220818074500
#
#                                            SOURCEURL
# 0  https://www.ktvu.com/news/thieves-steal-back-t...
# 1                     https://yle.fi/news/3-12581539
# 2                     https://yle.fi/news/3-12581539
# 3                     https://yle.fi/news/3-12581539
# 4                     https://yle.fi/news/3-12581539
#
# [5 rows x 61 columns]

# %%
# %%time
final_csv.to_csv(r".\GDELT_data.csv", index = False)
# Out:
# CPU times: total: 3.58 s
# Wall time: 3.67 s

# %% [markdown]
# ### Export data to MongoDB collection

# %%
import pymongo

# %%
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
client.list_database_names()
# Out:
# ['GDELT', 'TestGdelt', 'admin', 'config', 'local']

# %%
db = client['GDELT']

# %%
db.list_collection_names()
# Out:
# ['raw_data_files']

# %%
data = pd.read_csv(r".\GDELT_data.csv")

# %%
db.raw_data_files.insert_many(data.to_dict('records'))

# %%
payload = json.loads(data.to_json(orient='records'))

# %%
# %%time
db.raw_data_event.insert_many(payload)
# Out:
# CPU times: total: 7.08 s
# Wall time: 10.6 s
